# %%
import pandas as pd
path = "/Users/anthonandersson/Desktop/results-5.csv"
Colnames = ["parentid","trackid","particle","x","y","z","edep","gtime","ltime","copyno","seed"]
df = pd.read_csv(path,names=Colnames)
df.head(100)
# Out:
#     parentid  trackid       particle          x          y            z  \
# 0          1       54  opticalphoton  (-20.0361  15.308400     2.34648)
# 1          1       53  opticalphoton   (-20.342  16.258400   -0.847668)
# 2          1       52  opticalphoton   (22.4765  13.069600    -2.11776)
# 3          1       51  opticalphoton   (22.8356 -12.447500    -2.68241)
# 4          1       50  opticalphoton   (-23.191 -11.831900     1.96483)
# ..       ...      ...            ...        ...        ...          ...
# 95         1      507  opticalphoton   (23.2201  -9.677480      2.3607)
# 96         1      506  opticalphoton   (23.2677 -11.699100  -0.0534682)
# 97         1      505  opticalphoton       (-26  -0.638353    -1.40278)
# 98         1      504  opticalphoton  (-23.5986   9.277590     -1.3518)
# 99         1      503  opticalphoton  (-22.3951 -13.210600    -1.06479)
#
#         edep     gtime     ltime  copyno        seed
# ...

# %%
df.describe()
# Out:
#           parentid      trackid            y          edep        gtime  \
# count  6038.000000  6038.000000  6038.000000  6.038000e+03  6038.000000
# mean      2.942199  3162.107155    -0.069413  4.761285e-06     2.446862
# std      36.263166  1823.776408    18.350408  7.145281e-07     1.693067
# min       1.000000     3.000000   -26.000000  3.100400e-06     0.117494
# 25%       1.000000  1585.250000   -16.319600  4.018612e-06     1.300225
# 50%       1.000000  3166.500000    -0.245256  5.019470e-06     2.001465
# 75%       1.000000  4740.750000    16.442325  5.330880e-06     3.112367
# max    1130.000000  6320.000000    26.000000  5.889530e-06    14.852900
#
#              ltime       copyno        seed
# count  6038.000000  6038.000000      6038.0
# mean      1.716156     5.555482  13049000.0
# std       1.640901     3.459674         0.0
# min       0.106356     0.000000  13049000.0
# 25%       0.561512     3.000000  13049000.0
# 50%       1.206365     6.000000  13049000.0
# ...

# %%
df['trackid'].nunique()
# Out:
# 6038

# %%
df['gtime'].nunique()
# Out:
# 5998

# %%
ax = df['gtime'].hist(bins=100)
ax.set_xlabel("Time in ns")
ax.set_ylabel("Count of photons")
# Out:
# Text(0, 0.5, 'Count of photons')
